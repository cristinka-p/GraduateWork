# %% [markdown]
# <a href="https://colab.research.google.com/github/cristinka-p/GraduateWork/blob/master/wav_characteristics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Анализ звуковых характеристик
#
# ---

# %% [markdown]
# ## Чтение и воспроизведение нот от "до" до "си"

# %%
import IPython
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
import IPython.display as ipd
from scipy.io.wavfile import read
import matplotlib.pyplot as plt
from google.colab import drive

# %%
note_C = '/sounds of notes/zvuk-notyi-do.wav'
sr_C, data_C = read(note_C)
data_C = np.array(data_C, dtype=np.float64)

note_D = '/sounds of notes/zvuk-notyi-re.wav'
sr_D, data_D = read(note_D)
data_D = np.array(data_D, dtype=np.float64)

note_E = '/sounds of notes/zvuk-notyi-mi.wav'
sr_E, data_E = read(note_E)
data_E = np.array(data_E, dtype=np.float64)

note_F = '/sounds of notes/zvuk-notyi-fa.wav'
sr_F, data_F = read(note_F)
data_F = np.array(data_F, dtype=np.float64)

note_G = '/sounds of notes/zvuk-notyi-sol.wav'
sr_G, data_G = read(note_G)
data_G = np.array(data_G, dtype=np.float64)

note_A = '/sounds of notes/zvuk-notyi-lya.wav'
sr_A, data_A = read(note_A)
data_A = np.array(data_A, dtype=np.float64)

note_H = '/sounds of notes/zvuk-notyi-si.wav'
sr_H, data_H = read(note_H)
data_H = np.array(data_H, dtype=np.float64)

# %%
ipd.Audio(note_A)
ipd.Audio(note_H)
ipd.Audio(note_C)
ipd.Audio(note_D)
ipd.Audio(note_E)
ipd.Audio(note_F)
ipd.Audio(note_G)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Извлечение битов
#
# Из аудио можно получить темп и биты. Бит - отрезок времени, ритм. Обычно в такте 3-4 бита.
